# %%
import pandas as pd

df = pd.read_csv('Mountains.csv')
df.groupby(['Parent mountain']).size().reset_index(name='Count')
# Out:
#        Parent mountain  Count
# 0            Annapurna      1
# 1          Annapurna I      2
# 2        Annapurna III      1
# 3           Batura Sar      3
# 4              Cho Oyu      7
# 5            Chogolisa      2
# 6         Churen Himal      1
# 7           Dhaulagiri      4
# 8        Dhaulagiri II      1
# 9        Dhaulagiri IV      3
# 10       Distaghil Sar      5
# 11     Gangkar Puensum      2
# 12    Gangkhar Puensum      2
# 13        Gasherbrum I      8
# 14       Gasherbrum II      1
# 15      Gasherbrum III      1
# 16        Ghent Kangri      1
# 17  Ismail Samani Peak      1
# 18                  K2      5
# 19               Kamet      3
# 20       Kangchenjunga      7
# 21          Kanjut Sar      1
# 22     Khunyang Chhish      3
# 23         Kongur Tagh      2
# 24         Kula Kangri      1
# 25        Labuche Kang      1
# 26              Lhotse      2
# 27              Makalu      1
# 28          Malubiting      2
# 29             Manaslu      3
# ...
